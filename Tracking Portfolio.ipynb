# %% [markdown]
# # Machine Learning for Index Tracking Problem

# %% [markdown]
# By: Jean Philippe N'DRI

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
from sklearn.preprocessing import StandardScaler

#Import Model Packages 
from sklearn.cluster import AgglomerativeClustering,AffinityPropagation
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from scipy.spatial.distance import pdist
from sklearn.metrics import adjusted_mutual_info_score
from sklearn import cluster, covariance, manifold

import re
import warnings
warnings.filterwarnings('ignore')

# %%
def clean_name_col(name_col):
    res = name_col.lower()
    res = re.sub(r'[^\w\s]', '', res)
    return res

def list_col_supp(data,t):
    list_percent = (data.isnull().mean()*100)
    index_supp = [i for i, ele in enumerate(list_percent) if ele > t]
    return(data.iloc[:,index_supp].columns.to_list())

def list_row_supp(data):
    list_percent = data.isnull().sum(axis=1)/data.shape[0]
    index_supp = [i for i, ele in enumerate(list_percent) if ele > 50]
    return(index_supp)

def To_cat(ds):
    ds_cat = ds.select_dtypes(include = 'object').copy()
    return ds_cat

def To_num(ds):
    ds_num = ds.select_dtypes(exclude = 'object').copy()
    return ds_num

def download_adj_close(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data['Adj Close']

# %%
SOX_tickers=['AMD','ADI','AMAT','ASML','AZTA','AVGO','COHR','ENTG','GFS','INTC'
            ,'IPGP','KLAC','LRCX','LSCC','MRVL','MCHP','MU','MPWR','NOVT','NVDA'
            , 'NXPI','ON','QRVO','QCOM','SWKS','SYNA','TSM','TER','TXN','WOLF'
            ,'^SOX']

# %%
# Exemple d'utilisation
prices = download_adj_close(SOX_tickers, '2018-01-01', '2023-12-31')
prices
# Out:
# [*********************100%%**********************]  31 of 31 completed
#                    ADI        AMAT         AMD        ASML         AVGO  \
# Date
# 2018-01-02   80.471359   49.301422   10.980000  167.059860   216.090302
# 2018-01-03   81.469681   50.175159   11.550000  168.328827   218.453461
# 2018-01-04   81.380547   50.463318   12.120000  169.898544   218.526306
# 2018-01-05   81.710358   50.751461   11.880000  171.891266   219.821198
# 2018-01-08   81.852966   51.978424   12.280000  172.793640   220.347229
# ...                ...         ...         ...         ...          ...
# 2023-12-22  197.100006  162.050003  139.600006  752.530029  1121.979980
# 2023-12-26  198.869995  164.279999  143.410004  762.679993  1131.890015
# 2023-12-27  199.350006  164.210007  146.070007  764.030029  1126.170044
# 2023-12-28  200.240005  163.119995  148.759995  757.849976  1122.410034
# 2023-12-29  198.559998  162.070007  147.410004  756.919983  1116.250000
#
#                  AZTA       COHR        ENTG        GFS       INTC  ...  \
# Date                                                                ...
# 2018-01-02  23.732574  48.400002   30.606756        NaN  39.857136  ...
# 2018-01-03  23.915724  49.650002   30.655107        NaN  38.504452  ...
# 2018-01-04  24.465178  48.599998   31.186983        NaN  37.798340  ...
# 2018-01-05  25.178511  50.250000   31.670494        NaN  38.062077  ...
# 2018-01-08  25.139946  51.250000   32.299076        NaN  38.062077  ...
# ...               ...        ...         ...        ...        ...  ...
# 2023-12-22  64.489998  44.610001  119.912422  60.340000  48.000000  ...
# 2023-12-26  65.760002  45.430000  121.371239  61.990002  50.500000  ...
# 2023-12-27  66.300003  44.810001  121.501129  62.240002  50.759998  ...
# 2023-12-28  66.260002  44.810001  121.331268  61.509998  50.389999  ...
# 2023-12-29  65.139999  43.529999  119.722580  60.599998  50.250000  ...
#
#                    ON        QCOM        QRVO        SWKS        SYNA  \
# Date
# 2018-01-02  21.809999   55.204739   68.879997   88.106339   41.150002
# 2018-01-03  22.780001   55.831295   68.389999   89.449028   41.560001
# 2018-01-04  22.780001   55.907509   68.720001   90.200905   41.820000
# 2018-01-05  22.830000   56.280045   68.029999   90.612663   42.230000
# 2018-01-08  22.969999   56.110699   68.839996   90.630585   43.639999
# ...               ...         ...         ...         ...         ...
# 2023-12-22  84.010002  143.490005  112.599998  112.839996  118.029999
# 2023-12-26  85.470001  145.460007  114.379997  114.510002  118.879997
# 2023-12-27  85.050003  145.720001  114.610001  114.410004  118.470001
# 2023-12-28  84.980003  145.860001  114.180000  113.919998  117.089996
# 2023-12-29  83.529999  144.630005  112.610001  112.419998  114.080002
#
#                    TER         TSM         TXN       WOLF         ^SOX
# Date
# 2018-01-02   42.728653   34.790039   88.872917  38.139118  1287.699951
# 2018-01-03   42.912418   35.375248   91.280586  37.889126  1309.859985
# 2018-01-04   43.115513   35.188667   91.162735  38.619106  1317.239990
# 2018-01-05   44.111683   36.011349   91.861473  38.349113  1325.709961
# 2018-01-08   44.672615   35.994389   92.299232  38.569111  1335.540039
# ...                ...         ...         ...        ...          ...
# 2023-12-22  107.629997  103.150002  166.922775  44.430000  4132.850098
# 2023-12-26  110.349998  104.449997  169.472656  46.840000  4207.450195
# 2023-12-27  110.750000  104.650002  169.889359  46.509998  4214.589844
# 2023-12-28  110.440002  104.699997  170.375534  45.470001  4208.680176
# 2023-12-29  108.519997  104.000000  169.125397  43.509998  4175.470215
#
# [1509 rows x 31 columns]

# %%
for i in [5,10,20,30,40,50]:
    print(list_col_supp(prices,i))
# Out:
# ['GFS']
# ['GFS']
# ['GFS']
# ['GFS']
# ['GFS']
# ['GFS']

# %%
# Supprimer les actifs avec des valeurs Manquantes
elements_a_supprimer = ['GFS']
main_list = [element for element in SOX_tickers if element not in elements_a_supprimer]
prices=prices[main_list]

# %%
# Retrieve the first row (the starting point)
first_row = prices.iloc[0]

# Calculate the cumulative returns
# We divide each day's prices by the first day's prices
cumulative_returns = prices / first_row

# %%
# Plotting the evolution
# Setting the seaborn style
sns.set(style="ticks")
# Plotting the evolution using seaborn's lineplot
plt.figure(figsize=(20, 10))
for column in cumulative_returns.columns:
    sns.lineplot(data=cumulative_returns[column], label=column)

plt.title("Cumulative Returns of Top 10 Stocks and S&P 500")
plt.xlabel("Date")
plt.ylabel("Cumulative Returns")
plt.legend(title="Tickers")
plt.show()

# %%
# correlation
correlation = prices.corr()
plt.figure(figsize=(15,15))
plt.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=False)
# Out:
# <Axes: title={'center': 'Correlation Matrix'}>

# %%
#Calculate average annual percentage return and volatilities over a theoretical one year period
returns = prices.pct_change().mean() * 252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns['Volatility'] = prices.pct_change().std() * np.sqrt(252)
data=returns

#Scale the data
scaler = StandardScaler().fit(data)
rescaledDataset = pd.DataFrame(scaler.fit_transform(data),columns = data.columns, index = data.index)
# summarize transformed data
rescaledDataset.head(2)
X=rescaledDataset

# %%
X.head()
# Out:
#        Returns  Volatility
# AMD   2.389442    1.443046
# ADI  -0.566776   -1.495977
# AMAT  0.146429   -0.002985
# ASML  0.396170   -0.697304
# AZTA  0.232162    1.202784

# %% [markdown]
# # Selection Methods

# %% [markdown]
# ### Affinity Propagation Algorithm
#
# Affinity Propagation (AP) is a clustering algorithm that does not require the number of clusters to be determined before running the algorithm. It operates by passing messages between data points and considering all data points as potential exemplars (cluster centers).
#
# #### Key Concepts
#
# 1. **Exemplars**: Each cluster is represented by a data point known as an exemplar. Ideally, an exemplar is the most representative point of its cluster.
#
# 2. **Similarity**: The similarity (`s(i, k)`) between two points `i` and `k` is typically the negative square of the Euclidean distance. For a point `k`, the value of `s(k, k)`, called preference, influences the likelihood of `k` becoming an exemplar.
#
# #### Mathematical Formulations
#
# The algorithm proceeds by iteratively updating two types of messages:
#
# 1. **Responsibility** (`r(i, k)`): Sent from data point `i` to candidate exemplar `k`, this value reflects how well-suited `k` is to serve as the exemplar for `i`, considering other potential exemplars for `i`. It is calculated as:
#
#    $$ r(i, k) \leftarrow s(i, k) - \max_{k' \neq k} \left\{ a(i, k') + s(i, k') \right\} $$
#
#    where `a(i, k')` is the availability (see below) of point `k'` to be the exemplar for `i`.
#
# 2. **Availability** (`a(i, k)`): Sent from candidate exemplar `k` to data point `i`, this value indicates how appropriate it is for `i` to choose `k` as its exemplar, considering the support for `k` by other points that consider it their exemplar. It is calculated as:
#
#    $$ a(i, k) \leftarrow \min \left( 0, r(k, k) + \sum_{i' \notin \{ i, k \}} \max(0, r(i', k)) \right) $$
#
#    For `k` itself, the availability is updated differently:
#
#    $$ a(k, k) \leftarrow \sum_{i' \neq k} \max(0, r(i', k)) $$
#
# #### Algorithm Process
#
# 1. **Initialization**: Responsibilities and availabilities are initialized to zero.
#
# 2. **Message Updating**: Responsibilities and availabilities are updated according to the above formulas. These updates are done iteratively.
#
# 3. **Convergence**: The algorithm continues updating the messages until the decisions about exemplars remain unchanged for a certain number of consecutive iterations.
#
# 4. **Identifying Exemplars and Forming Clusters**: After convergence, data points for which the sum of responsibility and availability is positive (`r(i, k) + a(i, k) > 0`) are chosen as exemplars. Each data point is then assigned to the cluster of the most appropriate exemplar.
#
# #### Important Points
#
# - The choice of preferences (`s(k, k)`) is crucial. Higher values lead to more clusters, while lower values tend to produce fewer clusters.
# - Convergence parameters need to be carefully chosen to ensure a balance between accuracy and computational time.
# - AP can be more computationally intensive than other methods like K-means, especially for large datasets.
#
# In summary, Affinity Propagation is a powerful algorithm for clustering that identifies exemplars by considering the entire data set and their interactions, without the need for pre-specifying the number of clusters.

# %%
ap = AffinityPropagation(damping = 0.5, max_iter = 250, affinity = 'euclidean')
ap.fit(X)
clust_labels2 = ap.predict(X)

# %%
clust_labels2
# Out:
# array([4, 0, 2, 2, 1, 0, 1, 2, 0, 3, 2, 2, 4, 2, 5, 5, 2, 5, 4, 5, 1, 5,
#        5, 5, 1, 0, 5, 0, 1, 0])

# %%
cluster_label = pd.concat([pd.DataFrame(X.index), pd.DataFrame(clust_labels2)],axis = 1)
cluster_label.columns =['Company','Cluster']
cluster_label.sort_values(by=['Cluster'])
# Out:
#    Company  Cluster
# 29    ^SOX        0
# 1      ADI        0
# 25     TSM        0
# 27     TXN        0
# 5     AVGO        0
# 8     INTC        0
# 28    WOLF        1
# 24    SYNA        1
# 20      ON        1
# 6     COHR        1
# 4     AZTA        1
# 10    KLAC        2
# 11    LRCX        2
# 13    MRVL        2
# 3     ASML        2
# 2     AMAT        2
# 16    MPWR        2
# 7     ENTG        2
# 9     IPGP        3
# 0      AMD        4
# 18    NVDA        4
# 12    LSCC        4
# 21    QRVO        5
# 22    QCOM        5
# 23    SWKS        5
# 17    NOVT        5
# 15      MU        5
# 26     TER        5
# 19    NXPI        5
# 14    MCHP        5

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
scatter = ax.scatter(X.iloc[:,0],X.iloc[:,1], c =clust_labels2, cmap ="rainbow")
ax.set_title('Affinity')
ax.set_xlabel('Mean Return')
ax.set_ylabel('Volatility')
plt.colorbar(scatter)

# zip joins x and y coordinates in pairs
for x,y,name in zip(X.iloc[:,0],X.iloc[:,1],X.index):

    label = name

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %%
cluster_label.sort_values(by=['Cluster']).head()
# Out:
#    Company  Cluster
# 29    ^SOX        0
# 1      ADI        0
# 25     TSM        0
# 27     TXN        0
# 5     AVGO        0

# %%
for i in range(0,6):    
    # Retrieve the first row (the starting point)
    print(list(cluster_label[cluster_label['Cluster']==i].Company))
    first_row = prices[list(cluster_label[cluster_label['Cluster']==i].Company)].iloc[0]
    
    # Calculate the cumulative returns
    # We divide each day's prices by the first day's prices
    cumulative_returns = prices[list(cluster_label[cluster_label['Cluster']==i].Company)] / first_row

    # Plotting the evolution
    # Setting the seaborn style
    sns.set(style="ticks")
    # Plotting the evolution using seaborn's lineplot
    plt.figure(figsize=(12, 6))
    for column in cumulative_returns.columns:
        sns.lineplot(data=cumulative_returns[column], label=column)

    plt.title("Cumulative Returns of Stocks")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Returns")
    plt.legend(title="Tickers")
    plt.show()
# Out:
# ['ADI', 'AVGO', 'INTC', 'TSM', 'TXN', '^SOX']
# ['AZTA', 'COHR', 'ON', 'SYNA', 'WOLF']
# ['AMAT', 'ASML', 'ENTG', 'KLAC', 'LRCX', 'MRVL', 'MPWR']
# ['IPGP']
# ['AMD', 'LSCC', 'NVDA']
# ['MCHP', 'MU', 'NOVT', 'NXPI', 'QRVO', 'QCOM', 'SWKS', 'TER']

# %% [markdown]
# # AutoEncoder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras import regularizers, optimizers
from sklearn.preprocessing import MinMaxScaler

np.random.seed(101)

# %%
df_pct_change = prices.pct_change(1).astype(float)
df_pct_change = df_pct_change.replace([np.inf, -np.inf], np.nan)
df_pct_change = df_pct_change.fillna(method='ffill')

# the percentage change function will make the first two rows equal to nan
df_pct_change = df_pct_change.tail(len(df_pct_change) - 2)

# %%
df_pct_change=df_pct_change.iloc[:, :29]

# %%
# Normalize the data
df_scaler = MinMaxScaler()
df_pct_change_normalised = df_scaler.fit_transform(df_pct_change)

# %%
def create_autoencoder(learning_rate, lambda_reg, dropout_rate, num_stock, encoding_dim):
    """
    Creates, compiles, and returns an autoencoder based on specified parameters.
    :param learning_rate: Learning rate for the Adam optimizer.
    :param lambda_reg: Coefficient for L2 regularization applied to each Dense layer.
    :param dropout_rate: Dropout rate to reduce overfitting, applied after certain Dense layers.
    :param num_stock: Number of neurons in the input layer, corresponding to the dimension of the input data.
    :param encoding_dim: Size of the encoded representation, i.e., the number of neurons in the encoding layer.
    :return: A compiled Sequential autoencoder model.
    """
    # Initialize the Sequential model
    autoencoder = Sequential()
    # Add the input layer with the specified dimension
    autoencoder.add(Input(shape=(num_stock,)))
    # Add encoder hidden layers with L2 regularization and dropout
    # first hidden layers
    autoencoder.add(Dense(15, activation='relu', kernel_regularizer=regularizers.l2(lambda_reg)))
    autoencoder.add(Dropout(dropout_rate))
    # second hidden Layers
    autoencoder.add(Dense(10, activation='relu', kernel_regularizer=regularizers.l2(lambda_reg)))
    # Add the encoding layer, representing the compressed representation
    autoencoder.add(Dense(encoding_dim, kernel_regularizer=regularizers.l2(lambda_reg), name='Encoder_Input'))
    # Add decoder hidden layers, similar to encoder but in reverse
    # first hidden layers
    autoencoder.add(Dense(10, activation='relu', kernel_regularizer=regularizers.l2(lambda_reg)))
    autoencoder.add(Dropout(dropout_rate))
    # second hidden Layers
    autoencoder.add(Dense(15, activation='relu', kernel_regularizer=regularizers.l2(lambda_reg)))
    # Add the decoder output layer to reconstruct the input
    autoencoder.add(Dense(num_stock, activation='linear', kernel_regularizer=regularizers.l2(lambda_reg), name='Decoder_Input'))
    # Configure the optimizer with the specified learning rate
    optimizer = optimizers.Adam(learning_rate=learning_rate)
    # Compile the model with the optimizer and loss function
    autoencoder.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return autoencoder

# %%
def getReconstructionErrorsDF(df_pct_change, reconstructed_data):
    
    """
    Function for calculating the reconstruction Errors
    """
    array = []
    stocks_ranked = []
    num_columns = reconstructed_data.shape[1]
    for i in range(0, num_columns):
        diff = np.linalg.norm((df_pct_change.iloc[:, i] - reconstructed_data[:, i]))  # 2 norm difference
        array.append(float(diff))

    ranking = np.array(array).argsort()
    r = 1
    for stock_index in ranking:
        stocks_ranked.append([ r
                              ,stock_index
                              ,df_pct_change.iloc[:, stock_index].name
                              ,array[stock_index]
                              ])
        r = r + 1

    columns = ['ranking','stock_index', 'stock_name' ,'recreation_error']
    df = pd.DataFrame(stocks_ranked, columns=columns)
    df = df.set_index('stock_name')
    return df

# %%
# define the input parameters
hidden_layers = 5
batch_size = 500
epochs = 500
stock_selection_number = 10
num_stock = df_pct_change.shape[1]
verbose = 1
learning_rate=0.0004
lambda_reg=0.12
dropout_rate=0.80
num_stock=29
encoding_dim=5

# %%
# Exemple d'utilisation de la fonction
autoencoder_model = create_autoencoder(learning_rate, lambda_reg, dropout_rate, num_stock, encoding_dim)
autoencoder_model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 15)                450
#
#  dropout_14 (Dropout)        (None, 15)                0
#
#  dense_29 (Dense)            (None, 10)                160
#
#  Encoder_Input (Dense)       (None, 5)                 55
#
#  dense_30 (Dense)            (None, 10)                60
#
#  dropout_15 (Dropout)        (None, 10)                0
#
#  dense_31 (Dense)            (None, 15)                165
#
#  Decoder_Input (Dense)       (None, 29)                464
#
# =================================================================
# Total params: 1354 (5.29 KB)
# Trainable params: 1354 (5.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fitting
autoencoder_model.fit(df_pct_change_normalised, 
                      df_pct_change_normalised, 
                      epochs=epochs, 
                      batch_size=batch_size, 
                      validation_split=0.2)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 25ms/step - loss: 9.7352 - val_loss: 9.3035
# Epoch 2/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.6191 - val_loss: 9.2350
# Epoch 3/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.4678 - val_loss: 9.1666
# Epoch 4/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.4227 - val_loss: 9.0985
# Epoch 5/500
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2708 - val_loss: 9.0304
# Epoch 6/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.2486 - val_loss: 8.9623
# Epoch 7/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.1423 - val_loss: 8.8944
# Epoch 8/500
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0451 - val_loss: 8.8266
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.9630 - val_loss: 8.7591
# Epoch 10/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.8738 - val_loss: 8.6918
# Epoch 11/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.8071 - val_loss: 8.6249
# Epoch 12/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7172 - val_loss: 8.5583
# Epoch 13/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6482 - val_loss: 8.4921
# Epoch 14/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.5786 - val_loss: 8.4262
# Epoch 15/500
# 3/3 [==============================] - 0s 4ms/step - loss: 8.4843 - val_loss: 8.3608
# Epoch 16/500
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4269 - val_loss: 8.2957
# Epoch 17/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.3632 - val_loss: 8.2309
# Epoch 18/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2902 - val_loss: 8.1666
# Epoch 19/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2190 - val_loss: 8.1027
# Epoch 20/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1595 - val_loss: 8.0393
# Epoch 21/500
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0677 - val_loss: 7.9762
# Epoch 22/500
# 3/3 [==============================] - 0s 4ms/step - loss: 8.0065 - val_loss: 7.9134
# Epoch 23/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9374 - val_loss: 7.8510
# Epoch 24/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8785 - val_loss: 7.7891
# Epoch 25/500
# 3/3 [==============================] - 0s 4ms/step - loss: 7.8109 - val_loss: 7.7275
# Epoch 26/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7445 - val_loss: 7.6664
# Epoch 27/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6884 - val_loss: 7.6057
# Epoch 28/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6157 - val_loss: 7.5454
# Epoch 29/500
# 3/3 [==============================] - 0s 6ms/step - loss: 7.5593 - val_loss: 7.4856
# Epoch 30/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.5041 - val_loss: 7.4261
# Epoch 31/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4266 - val_loss: 7.3671
# Epoch 32/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3682 - val_loss: 7.3086
# Epoch 33/500
# 3/3 [==============================] - 0s 6ms/step - loss: 7.3110 - val_loss: 7.2504
# Epoch 34/500
# 3/3 [==============================] - 0s 4ms/step - loss: 7.2625 - val_loss: 7.1928
# Epoch 35/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.1947 - val_loss: 7.1355
# Epoch 36/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.1414 - val_loss: 7.0788
# Epoch 37/500
# 3/3 [==============================] - 0s 4ms/step - loss: 7.0888 - val_loss: 7.0224
# Epoch 38/500
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0232 - val_loss: 6.9665
# Epoch 39/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9742 - val_loss: 6.9110
# Epoch 40/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9100 - val_loss: 6.8559
# Epoch 41/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8575 - val_loss: 6.8013
# Epoch 42/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8046 - val_loss: 6.7471
# Epoch 43/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7500 - val_loss: 6.6933
# Epoch 44/500
# 3/3 [==============================] - 0s 4ms/step - loss: 6.6931 - val_loss: 6.6399
# Epoch 45/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.6423 - val_loss: 6.5869
# Epoch 46/500
# 3/3 [==============================] - 0s 8ms/step - loss: 6.5868 - val_loss: 6.5344
# Epoch 47/500
# 3/3 [==============================] - 0s 8ms/step - loss: 6.5320 - val_loss: 6.4822
# Epoch 48/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.4768 - val_loss: 6.4305
# Epoch 49/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.4310 - val_loss: 6.3792
# Epoch 50/500
# 3/3 [==============================] - 0s 4ms/step - loss: 6.3759 - val_loss: 6.3282
# Epoch 51/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.3243 - val_loss: 6.2777
# Epoch 52/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.2728 - val_loss: 6.2275
# Epoch 53/500
# 3/3 [==============================] - 0s 6ms/step - loss: 6.2258 - val_loss: 6.1777
# Epoch 54/500
# 3/3 [==============================] - 0s 6ms/step - loss: 6.1710 - val_loss: 6.1282
# Epoch 55/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.1213 - val_loss: 6.0791
# Epoch 56/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.0755 - val_loss: 6.0303
# Epoch 57/500
# 3/3 [==============================] - 0s 5ms/step - loss: 6.0248 - val_loss: 5.9819
# Epoch 58/500
# 3/3 [==============================] - 0s 8ms/step - loss: 5.9750 - val_loss: 5.9340
# Epoch 59/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.9302 - val_loss: 5.8864
# Epoch 60/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.8792 - val_loss: 5.8391
# Epoch 61/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.8343 - val_loss: 5.7923
# Epoch 62/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.7855 - val_loss: 5.7458
# Epoch 63/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.7395 - val_loss: 5.6996
# Epoch 64/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.6892 - val_loss: 5.6539
# Epoch 65/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.6441 - val_loss: 5.6084
# Epoch 66/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.5995 - val_loss: 5.5634
# Epoch 67/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.5554 - val_loss: 5.5187
# Epoch 68/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.5100 - val_loss: 5.4743
# Epoch 69/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.4670 - val_loss: 5.4303
# Epoch 70/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.4237 - val_loss: 5.3866
# Epoch 71/500
# 3/3 [==============================] - 0s 6ms/step - loss: 5.3788 - val_loss: 5.3433
# Epoch 72/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.3351 - val_loss: 5.3003
# Epoch 73/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.2927 - val_loss: 5.2576
# Epoch 74/500
# 3/3 [==============================] - 0s 6ms/step - loss: 5.2484 - val_loss: 5.2153
# Epoch 75/500
# 3/3 [==============================] - 0s 6ms/step - loss: 5.2065 - val_loss: 5.1733
# Epoch 76/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.1666 - val_loss: 5.1316
# Epoch 77/500
# 3/3 [==============================] - 0s 5ms/step - loss: 5.1242 - val_loss: 5.0903
# Epoch 78/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.0821 - val_loss: 5.0493
# Epoch 79/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.0414 - val_loss: 5.0086
# Epoch 80/500
# 3/3 [==============================] - 0s 4ms/step - loss: 5.0018 - val_loss: 4.9682
# Epoch 81/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.9610 - val_loss: 4.9281
# Epoch 82/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.9198 - val_loss: 4.8883
# Epoch 83/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8817 - val_loss: 4.8489
# Epoch 84/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8401 - val_loss: 4.8097
# Epoch 85/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8022 - val_loss: 4.7709
# Epoch 86/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.7624 - val_loss: 4.7323
# Epoch 87/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.7255 - val_loss: 4.6941
# Epoch 88/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.6855 - val_loss: 4.6561
# Epoch 89/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.6489 - val_loss: 4.6185
# Epoch 90/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.6090 - val_loss: 4.5811
# Epoch 91/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.5728 - val_loss: 4.5440
# Epoch 92/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.5351 - val_loss: 4.5072
# Epoch 93/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.4992 - val_loss: 4.4707
# Epoch 94/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.4630 - val_loss: 4.4345
# Epoch 95/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.4251 - val_loss: 4.3986
# Epoch 96/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.3897 - val_loss: 4.3629
# Epoch 97/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.3542 - val_loss: 4.3275
# Epoch 98/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.3182 - val_loss: 4.2924
# Epoch 99/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.2838 - val_loss: 4.2576
# Epoch 100/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.2496 - val_loss: 4.2231
# Epoch 101/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.2136 - val_loss: 4.1888
# Epoch 102/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.1795 - val_loss: 4.1548
# Epoch 103/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.1459 - val_loss: 4.1210
# Epoch 104/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.1129 - val_loss: 4.0875
# Epoch 105/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.0782 - val_loss: 4.0543
# Epoch 106/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.0457 - val_loss: 4.0213
# Epoch 107/500
# 3/3 [==============================] - 0s 4ms/step - loss: 4.0121 - val_loss: 3.9886
# Epoch 108/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.9801 - val_loss: 3.9562
# Epoch 109/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.9486 - val_loss: 3.9240
# Epoch 110/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.9152 - val_loss: 3.8920
# Epoch 111/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8843 - val_loss: 3.8603
# Epoch 112/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8522 - val_loss: 3.8289
# Epoch 113/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8206 - val_loss: 3.7977
# Epoch 114/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.7901 - val_loss: 3.7667
# Epoch 115/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.7590 - val_loss: 3.7360
# Epoch 116/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.7277 - val_loss: 3.7055
# Epoch 117/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6970 - val_loss: 3.6753
# Epoch 118/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6671 - val_loss: 3.6453
# Epoch 119/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6378 - val_loss: 3.6155
# Epoch 120/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6076 - val_loss: 3.5859
# Epoch 121/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5780 - val_loss: 3.5566
# Epoch 122/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5489 - val_loss: 3.5276
# Epoch 123/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5200 - val_loss: 3.4987
# Epoch 124/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.4914 - val_loss: 3.4701
# Epoch 125/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.4629 - val_loss: 3.4417
# Epoch 126/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.4335 - val_loss: 3.4135
# Epoch 127/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.4059 - val_loss: 3.3856
# Epoch 128/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3781 - val_loss: 3.3578
# Epoch 129/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3495 - val_loss: 3.3303
# Epoch 130/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3225 - val_loss: 3.3030
# Epoch 131/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2952 - val_loss: 3.2759
# Epoch 132/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2686 - val_loss: 3.2490
# Epoch 133/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2420 - val_loss: 3.2224
# Epoch 134/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2152 - val_loss: 3.1959
# Epoch 135/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1887 - val_loss: 3.1697
# Epoch 136/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1623 - val_loss: 3.1436
# Epoch 137/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1363 - val_loss: 3.1178
# Epoch 138/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1105 - val_loss: 3.0921
# Epoch 139/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0852 - val_loss: 3.0667
# Epoch 140/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0599 - val_loss: 3.0415
# Epoch 141/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0343 - val_loss: 3.0164
# Epoch 142/500
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0095 - val_loss: 2.9916
# Epoch 143/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.9843 - val_loss: 2.9669
# Epoch 144/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.9596 - val_loss: 2.9425
# Epoch 145/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.9357 - val_loss: 2.9182
# Epoch 146/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.9114 - val_loss: 2.8941
# Epoch 147/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8877 - val_loss: 2.8703
# Epoch 148/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8631 - val_loss: 2.8466
# Epoch 149/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8398 - val_loss: 2.8230
# Epoch 150/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8163 - val_loss: 2.7997
# Epoch 151/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7929 - val_loss: 2.7766
# Epoch 152/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7699 - val_loss: 2.7536
# Epoch 153/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7468 - val_loss: 2.7308
# Epoch 154/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7239 - val_loss: 2.7082
# Epoch 155/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7015 - val_loss: 2.6858
# Epoch 156/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6795 - val_loss: 2.6636
# Epoch 157/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6572 - val_loss: 2.6415
# Epoch 158/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6352 - val_loss: 2.6196
# Epoch 159/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6132 - val_loss: 2.5979
# Epoch 160/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5915 - val_loss: 2.5764
# Epoch 161/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5702 - val_loss: 2.5550
# Epoch 162/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5486 - val_loss: 2.5338
# Epoch 163/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5277 - val_loss: 2.5128
# Epoch 164/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5065 - val_loss: 2.4919
# Epoch 165/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4857 - val_loss: 2.4712
# Epoch 166/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4652 - val_loss: 2.4507
# Epoch 167/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4446 - val_loss: 2.4303
# Epoch 168/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4245 - val_loss: 2.4101
# Epoch 169/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4041 - val_loss: 2.3901
# Epoch 170/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.3842 - val_loss: 2.3702
# Epoch 171/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.3643 - val_loss: 2.3505
# Epoch 172/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.3445 - val_loss: 2.3309
# Epoch 173/500
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3252 - val_loss: 2.3115
# Epoch 174/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.3058 - val_loss: 2.2922
# Epoch 175/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2866 - val_loss: 2.2731
# Epoch 176/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2675 - val_loss: 2.2542
# Epoch 177/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2484 - val_loss: 2.2354
# Epoch 178/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2299 - val_loss: 2.2167
# Epoch 179/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2111 - val_loss: 2.1982
# Epoch 180/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1927 - val_loss: 2.1799
# Epoch 181/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1745 - val_loss: 2.1617
# Epoch 182/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1563 - val_loss: 2.1436
# Epoch 183/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1384 - val_loss: 2.1257
# Epoch 184/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1204 - val_loss: 2.1079
# Epoch 185/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1028 - val_loss: 2.0903
# Epoch 186/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0852 - val_loss: 2.0728
# Epoch 187/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0676 - val_loss: 2.0555
# Epoch 188/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0505 - val_loss: 2.0383
# Epoch 189/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0332 - val_loss: 2.0212
# Epoch 190/500
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0163 - val_loss: 2.0042
# Epoch 191/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9993 - val_loss: 1.9875
# Epoch 192/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9826 - val_loss: 1.9708
# Epoch 193/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9658 - val_loss: 1.9543
# Epoch 194/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9494 - val_loss: 1.9379
# Epoch 195/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9330 - val_loss: 1.9216
# Epoch 196/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9169 - val_loss: 1.9055
# Epoch 197/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9007 - val_loss: 1.8895
# Epoch 198/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8847 - val_loss: 1.8736
# Epoch 199/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8688 - val_loss: 1.8578
# Epoch 200/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8532 - val_loss: 1.8422
# Epoch 201/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8377 - val_loss: 1.8267
# Epoch 202/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8223 - val_loss: 1.8114
# Epoch 203/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8069 - val_loss: 1.7961
# Epoch 204/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7916 - val_loss: 1.7810
# Epoch 205/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7765 - val_loss: 1.7660
# Epoch 206/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7615 - val_loss: 1.7511
# Epoch 207/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7467 - val_loss: 1.7363
# Epoch 208/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7319 - val_loss: 1.7217
# Epoch 209/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7174 - val_loss: 1.7072
# Epoch 210/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7029 - val_loss: 1.6928
# Epoch 211/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6885 - val_loss: 1.6785
# Epoch 212/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6743 - val_loss: 1.6643
# Epoch 213/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6601 - val_loss: 1.6502
# Epoch 214/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6461 - val_loss: 1.6363
# Epoch 215/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6322 - val_loss: 1.6225
# Epoch 216/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6184 - val_loss: 1.6087
# Epoch 217/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6047 - val_loss: 1.5951
# Epoch 218/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5912 - val_loss: 1.5816
# Epoch 219/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5777 - val_loss: 1.5682
# Epoch 220/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5643 - val_loss: 1.5550
# Epoch 221/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5511 - val_loss: 1.5418
# Epoch 222/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5379 - val_loss: 1.5287
# Epoch 223/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5248 - val_loss: 1.5158
# Epoch 224/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5120 - val_loss: 1.5029
# Epoch 225/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4992 - val_loss: 1.4901
# Epoch 226/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4866 - val_loss: 1.4775
# Epoch 227/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4738 - val_loss: 1.4650
# Epoch 228/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4613 - val_loss: 1.4525
# Epoch 229/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4488 - val_loss: 1.4402
# Epoch 230/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4366 - val_loss: 1.4279
# Epoch 231/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4243 - val_loss: 1.4158
# Epoch 232/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4122 - val_loss: 1.4037
# Epoch 233/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4002 - val_loss: 1.3918
# Epoch 234/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3883 - val_loss: 1.3800
# Epoch 235/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3765 - val_loss: 1.3682
# Epoch 236/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3648 - val_loss: 1.3565
# Epoch 237/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3532 - val_loss: 1.3450
# Epoch 238/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3416 - val_loss: 1.3335
# Epoch 239/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3302 - val_loss: 1.3222
# Epoch 240/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3189 - val_loss: 1.3109
# Epoch 241/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3076 - val_loss: 1.2997
# Epoch 242/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2964 - val_loss: 1.2886
# Epoch 243/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2854 - val_loss: 1.2776
# Epoch 244/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2744 - val_loss: 1.2667
# Epoch 245/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2635 - val_loss: 1.2559
# Epoch 246/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2527 - val_loss: 1.2451
# Epoch 247/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2420 - val_loss: 1.2345
# Epoch 248/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2314 - val_loss: 1.2239
# Epoch 249/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2208 - val_loss: 1.2134
# Epoch 250/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2104 - val_loss: 1.2030
# Epoch 251/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2000 - val_loss: 1.1927
# Epoch 252/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1898 - val_loss: 1.1825
# Epoch 253/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1796 - val_loss: 1.1724
# Epoch 254/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1695 - val_loss: 1.1623
# Epoch 255/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1594 - val_loss: 1.1524
# Epoch 256/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1495 - val_loss: 1.1425
# Epoch 257/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1396 - val_loss: 1.1327
# Epoch 258/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1299 - val_loss: 1.1230
# Epoch 259/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1202 - val_loss: 1.1133
# Epoch 260/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1106 - val_loss: 1.1038
# Epoch 261/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1010 - val_loss: 1.0943
# Epoch 262/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0916 - val_loss: 1.0849
# Epoch 263/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0822 - val_loss: 1.0756
# Epoch 264/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0728 - val_loss: 1.0663
# Epoch 265/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0637 - val_loss: 1.0571
# Epoch 266/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0545 - val_loss: 1.0480
# Epoch 267/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0454 - val_loss: 1.0390
# Epoch 268/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0364 - val_loss: 1.0301
# Epoch 269/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0276 - val_loss: 1.0212
# Epoch 270/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0186 - val_loss: 1.0124
# Epoch 271/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0099 - val_loss: 1.0037
# Epoch 272/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0012 - val_loss: 0.9950
# Epoch 273/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9925 - val_loss: 0.9864
# Epoch 274/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9840 - val_loss: 0.9779
# Epoch 275/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9755 - val_loss: 0.9695
# Epoch 276/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9671 - val_loss: 0.9611
# Epoch 277/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9587 - val_loss: 0.9528
# Epoch 278/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9504 - val_loss: 0.9446
# Epoch 279/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9422 - val_loss: 0.9364
# Epoch 280/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9341 - val_loss: 0.9283
# Epoch 281/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9261 - val_loss: 0.9203
# Epoch 282/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9180 - val_loss: 0.9123
# Epoch 283/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9101 - val_loss: 0.9044
# Epoch 284/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9022 - val_loss: 0.8966
# Epoch 285/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8944 - val_loss: 0.8888
# Epoch 286/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8867 - val_loss: 0.8811
# Epoch 287/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8789 - val_loss: 0.8735
# Epoch 288/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8713 - val_loss: 0.8659
# Epoch 289/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8637 - val_loss: 0.8584
# Epoch 290/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8564 - val_loss: 0.8510
# Epoch 291/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8489 - val_loss: 0.8436
# Epoch 292/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8415 - val_loss: 0.8363
# Epoch 293/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8342 - val_loss: 0.8290
# Epoch 294/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8270 - val_loss: 0.8218
# Epoch 295/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8198 - val_loss: 0.8147
# Epoch 296/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8127 - val_loss: 0.8076
# Epoch 297/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8056 - val_loss: 0.8006
# Epoch 298/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7986 - val_loss: 0.7936
# Epoch 299/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7917 - val_loss: 0.7867
# Epoch 300/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7847 - val_loss: 0.7799
# Epoch 301/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7780 - val_loss: 0.7731
# Epoch 302/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7712 - val_loss: 0.7663
# Epoch 303/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7645 - val_loss: 0.7597
# Epoch 304/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7578 - val_loss: 0.7531
# Epoch 305/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7512 - val_loss: 0.7465
# Epoch 306/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7447 - val_loss: 0.7400
# Epoch 307/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7382 - val_loss: 0.7335
# Epoch 308/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7317 - val_loss: 0.7271
# Epoch 309/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7254 - val_loss: 0.7208
# Epoch 310/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7190 - val_loss: 0.7145
# Epoch 311/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7128 - val_loss: 0.7083
# Epoch 312/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7065 - val_loss: 0.7021
# Epoch 313/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7004 - val_loss: 0.6959
# Epoch 314/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6943 - val_loss: 0.6899
# Epoch 315/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6882 - val_loss: 0.6838
# Epoch 316/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6822 - val_loss: 0.6778
# Epoch 317/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6762 - val_loss: 0.6719
# Epoch 318/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6703 - val_loss: 0.6660
# Epoch 319/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6645 - val_loss: 0.6602
# Epoch 320/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6586 - val_loss: 0.6544
# Epoch 321/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6529 - val_loss: 0.6487
# Epoch 322/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6471 - val_loss: 0.6430
# Epoch 323/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6415 - val_loss: 0.6374
# Epoch 324/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6359 - val_loss: 0.6318
# Epoch 325/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6303 - val_loss: 0.6263
# Epoch 326/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6247 - val_loss: 0.6208
# Epoch 327/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6193 - val_loss: 0.6153
# Epoch 328/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6139 - val_loss: 0.6099
# Epoch 329/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6085 - val_loss: 0.6046
# Epoch 330/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6031 - val_loss: 0.5992
# Epoch 331/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5979 - val_loss: 0.5940
# Epoch 332/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5926 - val_loss: 0.5888
# Epoch 333/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5874 - val_loss: 0.5836
# Epoch 334/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5822 - val_loss: 0.5785
# Epoch 335/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5771 - val_loss: 0.5734
# Epoch 336/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5721 - val_loss: 0.5683
# Epoch 337/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5670 - val_loss: 0.5633
# Epoch 338/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5620 - val_loss: 0.5584
# Epoch 339/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5571 - val_loss: 0.5535
# Epoch 340/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5522 - val_loss: 0.5486
# Epoch 341/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5473 - val_loss: 0.5437
# Epoch 342/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5425 - val_loss: 0.5390
# Epoch 343/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5377 - val_loss: 0.5342
# Epoch 344/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5330 - val_loss: 0.5295
# Epoch 345/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5283 - val_loss: 0.5248
# Epoch 346/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5236 - val_loss: 0.5202
# Epoch 347/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5190 - val_loss: 0.5156
# Epoch 348/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5144 - val_loss: 0.5110
# Epoch 349/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5099 - val_loss: 0.5065
# Epoch 350/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5054 - val_loss: 0.5021
# Epoch 351/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5010 - val_loss: 0.4976
# Epoch 352/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4965 - val_loss: 0.4932
# Epoch 353/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4921 - val_loss: 0.4889
# Epoch 354/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4878 - val_loss: 0.4845
# Epoch 355/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4835 - val_loss: 0.4803
# Epoch 356/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4792 - val_loss: 0.4760
# Epoch 357/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4749 - val_loss: 0.4718
# Epoch 358/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4707 - val_loss: 0.4676
# Epoch 359/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4666 - val_loss: 0.4635
# Epoch 360/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4625 - val_loss: 0.4594
# Epoch 361/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4584 - val_loss: 0.4553
# Epoch 362/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4543 - val_loss: 0.4513
# Epoch 363/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4503 - val_loss: 0.4473
# Epoch 364/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4463 - val_loss: 0.4433
# Epoch 365/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4423 - val_loss: 0.4394
# Epoch 366/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4384 - val_loss: 0.4355
# Epoch 367/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4345 - val_loss: 0.4316
# Epoch 368/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4307 - val_loss: 0.4278
# Epoch 369/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4269 - val_loss: 0.4240
# Epoch 370/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4231 - val_loss: 0.4202
# Epoch 371/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4193 - val_loss: 0.4165
# Epoch 372/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4156 - val_loss: 0.4128
# Epoch 373/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4119 - val_loss: 0.4091
# Epoch 374/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4082 - val_loss: 0.4055
# Epoch 375/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4046 - val_loss: 0.4019
# Epoch 376/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4010 - val_loss: 0.3983
# Epoch 377/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3975 - val_loss: 0.3947
# Epoch 378/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3939 - val_loss: 0.3912
# Epoch 379/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3904 - val_loss: 0.3877
# Epoch 380/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3869 - val_loss: 0.3843
# Epoch 381/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3835 - val_loss: 0.3809
# Epoch 382/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3801 - val_loss: 0.3775
# Epoch 383/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3767 - val_loss: 0.3741
# Epoch 384/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3733 - val_loss: 0.3708
# Epoch 385/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3700 - val_loss: 0.3675
# Epoch 386/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3667 - val_loss: 0.3642
# Epoch 387/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3635 - val_loss: 0.3609
# Epoch 388/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3602 - val_loss: 0.3577
# Epoch 389/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3570 - val_loss: 0.3545
# Epoch 390/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3538 - val_loss: 0.3513
# Epoch 391/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3506 - val_loss: 0.3482
# Epoch 392/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3475 - val_loss: 0.3451
# Epoch 393/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3444 - val_loss: 0.3420
# Epoch 394/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3414 - val_loss: 0.3389
# Epoch 395/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3383 - val_loss: 0.3359
# Epoch 396/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3353 - val_loss: 0.3329
# Epoch 397/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3323 - val_loss: 0.3299
# Epoch 398/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3293 - val_loss: 0.3270
# Epoch 399/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3264 - val_loss: 0.3241
# Epoch 400/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3235 - val_loss: 0.3212
# Epoch 401/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3206 - val_loss: 0.3183
# Epoch 402/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3177 - val_loss: 0.3154
# Epoch 403/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3149 - val_loss: 0.3126
# Epoch 404/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3120 - val_loss: 0.3098
# Epoch 405/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3092 - val_loss: 0.3070
# Epoch 406/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3065 - val_loss: 0.3043
# Epoch 407/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3038 - val_loss: 0.3015
# Epoch 408/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3010 - val_loss: 0.2988
# Epoch 409/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2983 - val_loss: 0.2961
# Epoch 410/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2956 - val_loss: 0.2935
# Epoch 411/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2930 - val_loss: 0.2909
# Epoch 412/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2904 - val_loss: 0.2882
# Epoch 413/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2878 - val_loss: 0.2857
# Epoch 414/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2852 - val_loss: 0.2831
# Epoch 415/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2826 - val_loss: 0.2805
# Epoch 416/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2801 - val_loss: 0.2780
# Epoch 417/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2776 - val_loss: 0.2755
# Epoch 418/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2751 - val_loss: 0.2730
# Epoch 419/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2726 - val_loss: 0.2706
# Epoch 420/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2702 - val_loss: 0.2681
# Epoch 421/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2677 - val_loss: 0.2657
# Epoch 422/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2653 - val_loss: 0.2633
# Epoch 423/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2630 - val_loss: 0.2610
# Epoch 424/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2606 - val_loss: 0.2586
# Epoch 425/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2582 - val_loss: 0.2563
# Epoch 426/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2559 - val_loss: 0.2540
# Epoch 427/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2536 - val_loss: 0.2517
# Epoch 428/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2513 - val_loss: 0.2494
# Epoch 429/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2491 - val_loss: 0.2472
# Epoch 430/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2468 - val_loss: 0.2449
# Epoch 431/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2446 - val_loss: 0.2427
# Epoch 432/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2424 - val_loss: 0.2405
# Epoch 433/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2402 - val_loss: 0.2384
# Epoch 434/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2381 - val_loss: 0.2362
# Epoch 435/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2359 - val_loss: 0.2341
# Epoch 436/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2338 - val_loss: 0.2320
# Epoch 437/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2317 - val_loss: 0.2299
# Epoch 438/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2296 - val_loss: 0.2278
# Epoch 439/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2275 - val_loss: 0.2257
# Epoch 440/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2255 - val_loss: 0.2237
# Epoch 441/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2235 - val_loss: 0.2217
# Epoch 442/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2214 - val_loss: 0.2197
# Epoch 443/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2194 - val_loss: 0.2177
# Epoch 444/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2175 - val_loss: 0.2157
# Epoch 445/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2155 - val_loss: 0.2138
# Epoch 446/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2135 - val_loss: 0.2118
# Epoch 447/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2116 - val_loss: 0.2099
# Epoch 448/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2097 - val_loss: 0.2080
# Epoch 449/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2078 - val_loss: 0.2061
# Epoch 450/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2059 - val_loss: 0.2043
# Epoch 451/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2041 - val_loss: 0.2024
# Epoch 452/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2022 - val_loss: 0.2006
# Epoch 453/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2004 - val_loss: 0.1987
# Epoch 454/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1986 - val_loss: 0.1969
# Epoch 455/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1968 - val_loss: 0.1952
# Epoch 456/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1950 - val_loss: 0.1934
# Epoch 457/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1933 - val_loss: 0.1916
# Epoch 458/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1915 - val_loss: 0.1899
# Epoch 459/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1898 - val_loss: 0.1882
# Epoch 460/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1881 - val_loss: 0.1865
# Epoch 461/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1864 - val_loss: 0.1848
# Epoch 462/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1847 - val_loss: 0.1831
# Epoch 463/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1830 - val_loss: 0.1814
# Epoch 464/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1813 - val_loss: 0.1798
# Epoch 465/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1797 - val_loss: 0.1781
# Epoch 466/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1781 - val_loss: 0.1765
# Epoch 467/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1765 - val_loss: 0.1749
# Epoch 468/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1749 - val_loss: 0.1733
# Epoch 469/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1733 - val_loss: 0.1718
# Epoch 470/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1717 - val_loss: 0.1702
# Epoch 471/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1701 - val_loss: 0.1686
# Epoch 472/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1686 - val_loss: 0.1671
# Epoch 473/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1671 - val_loss: 0.1656
# Epoch 474/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1656 - val_loss: 0.1641
# Epoch 475/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1641 - val_loss: 0.1626
# Epoch 476/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1626 - val_loss: 0.1611
# Epoch 477/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1611 - val_loss: 0.1596
# Epoch 478/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1596 - val_loss: 0.1582
# Epoch 479/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1582 - val_loss: 0.1567
# Epoch 480/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1567 - val_loss: 0.1553
# Epoch 481/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1553 - val_loss: 0.1539
# Epoch 482/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1539 - val_loss: 0.1525
# Epoch 483/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1525 - val_loss: 0.1511
# Epoch 484/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1511 - val_loss: 0.1497
# Epoch 485/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1498 - val_loss: 0.1484
# Epoch 486/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1484 - val_loss: 0.1470
# Epoch 487/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1471 - val_loss: 0.1457
# Epoch 488/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1457 - val_loss: 0.1443
# Epoch 489/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1444 - val_loss: 0.1430
# Epoch 490/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1431 - val_loss: 0.1417
# Epoch 491/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1418 - val_loss: 0.1404
# Epoch 492/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1405 - val_loss: 0.1391
# Epoch 493/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1392 - val_loss: 0.1379
# Epoch 494/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1380 - val_loss: 0.1366
# Epoch 495/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1367 - val_loss: 0.1354
# Epoch 496/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1355 - val_loss: 0.1341
# Epoch 497/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1342 - val_loss: 0.1329
# Epoch 498/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1330 - val_loss: 0.1317
# Epoch 499/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1318 - val_loss: 0.1305
# Epoch 500/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1306 - val_loss: 0.1293

# %%
# predict autoencoder
print('-' * 25 + 'Predict autoencoder model')
reconstruct = autoencoder_model.predict(df_pct_change_normalised)
# Out:
# -------------------------Predict autoencoder model
# 48/48 [==============================] - 0s 297us/step

# %%
# Inverse transform dataset with MinMax Scaler
print('-' * 25 + 'Inverse transform dataset with MinMax Scaler')
reconstruct_real = df_scaler.inverse_transform(reconstruct)
df_reconstruct_real = pd.DataFrame(data=reconstruct_real, columns=df_pct_change.columns)
# Out:
# -------------------------Inverse transform dataset with MinMax Scaler

# %%
print('-' * 25 + 'Calculate L2 norm as reconstruction loss metric')
df_recreation_error = getReconstructionErrorsDF(df_pct_change=df_pct_change,
                                                reconstructed_data=reconstruct_real)
# Out:
# -------------------------Calculate L2 norm as reconstruction loss metric

# %%
df_recreation_error
# Out:
#             ranking  stock_index  recreation_error
# stock_name
# TXN               1           27          0.921905
# NOVT              2           17          1.026651
# QCOM              3           22          1.084832
# QRVO              4           21          1.151377
# MRVL              5           13          1.196001
# SWKS              6           23          1.262401
# TSM               7           25          1.272336
# AZTA              8            4          1.325241
# LSCC              9           12          1.331084
# KLAC             10           10          1.340649
# INTC             11            8          1.377240
# ADI              12            1          1.438452
# NVDA             13           18          1.442073
# LRCX             14           11          1.449977
# WOLF             15           28          1.544797
# AMD              16            0          1.583447
# ASML             17            3          1.606890
# ENTG             18            7          1.618867
# NXPI             19           19          1.664870
# MPWR             20           16          1.796022
# TER              21           26          1.805608
# AVGO             22            5          1.830160
# IPGP             23            9          1.876261
# AMAT             24            2          2.049671
# MU               25           15          2.062519
# SYNA             26           24          2.137311
# MCHP             27           14          2.152348
# ON               28           20          2.178904
# COHR             29            6          3.198933

# %%
Autoencoder_stocks = list(df_recreation_error.head(10).index)
Autoencoder_stocks.append('^SOX')

# %% [markdown]
# # Gradient Descent Optimization
#
# #### Objective function
#
# The objective function is defined by :
# \begin{equation}
# f(W) = (R_i - R_xW)^T(R_i - R_xW) - k(W^TW)
# \end{equation}
# where $R_i$ and $R_x$ are known matrices, $W$ is the variable matrix, and $k$ is a scalar and $k(W^TW)$ is the regularized term
#
# #### Gradient of the function
#
# The gradient of $f(W)$ with respect to $W$ is calculated as follows:
#
# \begin{align}
# \nabla f(W) &= -2R_x^T(R_i - R_xW) - 2kW
# \end{align}
#
# #### Gradient descent algorithm
#
# The algorithm for minimizing $f(W)$ is shown below:
#
# **Algorithm: Gradient descent to minimize $f(W)$**
#
# 1. **Set** $W$ to an arbitrary value.
# 2. Choose a learning rate $\alpha$ and a convergence threshold $\epsilon$.
# 3. **Repeat** :
#    - Calculate the gradient $\nabla f(W)$.
#    - Update $W \leftarrow W - \alpha \nabla f(W)$.
# 4. **Until** the norm of $\nabla f(W)$ is less than $\epsilon$.

# %%
np.random.seed(101) 
class GradientDescentOptimizer:
    def __init__(self, R_i, R_x, alpha=0.01, epsilon=1e-6, max_iter=10000):
        self.R_i = R_i  # Return vector for asset/portfolio i (n, 1)
        self.R_x = R_x  # Matrix of explanatory variables/factors (n, k)
        self.alpha = alpha  # Learning rate
        self.epsilon = epsilon  # Convergence threshold
        self.max_iter = max_iter  # Maximum number of iterations

    def calculate_gradient(self, W, k):
        # Calculate the gradient of the cost function
        predictions = np.dot(self.R_x, W)
        error = self.R_i - predictions
        gradient = -2 * np.dot(self.R_x.T, error) + 2 * k * W
        return gradient

    def cost_function(self, W, k):
        # Calculate the cost function including the regularization term
        predictions = np.dot(self.R_x, W)
        error = self.R_i - predictions
        cost = np.dot(error.T, error) + k * np.dot(W.T, W)
        return cost.item()

    def optimize_W_for_k(self, k):
        W = np.random.randn(self.R_x.shape[1], 1)  # Initialize W as a vector (k, 1)
        for _ in range(self.max_iter):
            gradient = self.calculate_gradient(W, k)
            W -= self.alpha * gradient
            if np.linalg.norm(gradient) < self.epsilon:
                break
        return W, self.cost_function(W, k)

    def find_best_k(self, k_values):
        min_cost = np.inf
        best_k = None
        best_W = None
        for k in k_values:
            W, cost = self.optimize_W_for_k(k)
            if cost < min_cost:
                min_cost = cost
                best_k = k
                best_W = W
        return best_k, best_W, min_cost

# %% [markdown]
# ## Tracking Problem resolution

# %% [markdown]
# #### Tracking Using all stocks

# %%
#df of return
df=prices.pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(train_data[['^SOX']])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:29])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_full, min_cost = optimizer.find_best_k(k_values)

#Best Parameters
print("Best k:", best_k)
print("Optimized W:")
print(best_W_full*100)
print("Minimum cost:", min_cost)
# Out:
# Best k: 0.01
# Optimized W:
# [[ 4.51893286e+00]
#  [ 4.09294633e+00]
#  [ 4.40521839e+00]
#  [ 3.06520324e+00]
#  [ 4.12501035e-01]
#  [ 6.99759178e+00]
#  [-4.99859741e-03]
#  [ 2.00937088e+00]
#  [ 7.99908200e+00]
#  [ 5.18390672e-01]
#  [ 4.05188741e+00]
#  [ 4.07079968e+00]
#  [ 2.57237494e-01]
#  [ 3.47672810e+00]
#  [ 4.53586506e+00]
#  [ 3.68110118e+00]
#  [ 2.74309341e+00]
#  [ 2.69174699e-01]
#  [ 7.91918727e+00]
#  [ 2.24840485e+00]
#  [ 1.56887407e+00]
#  [ 2.15162201e+00]
#  [ 8.48718941e+00]
#  [ 2.77045666e+00]
#  [ 1.77905579e-01]
#  [ 4.97515158e+00]
#  [ 2.37074207e+00]
#  [ 8.80360028e+00]
#  [ 1.01295409e+00]]
# Minimum cost: 0.001620327401858098

# %%
best_W_full.sum()
# Out:
# 0.9958622118704334

# %% [markdown]
# #### Tracking with AutoEncoder Selection

# %%
#df of return
df=prices[Autoencoder_stocks].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(train_data[['^SOX']])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:10])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AE, min_cost = optimizer.find_best_k(k_values)

#Best Parameters
print("Best k:", best_k)
print("Optimized W:")
print(best_W_AE*100)
print("Minimum cost:", min_cost)

# %%
best_W_AE.sum()

# %% [markdown]
# #### Tracking with Affinity Propagation Selection

# %%
# Initialize an empty list to hold all affinity selections
affinity_selections = []

# Iterate through the cluster numbers you're interested in combining with cluster 0
for cluster_num in range(1, 6): 
    # Create a selection list by starting with companies from cluster 0
    selection = list(cluster_label[cluster_label['Cluster'] == 0].Company)
    
    # Extend the selection by adding companies from the current cluster
    selection.extend(list(cluster_label[cluster_label['Cluster'] == cluster_num].Company))
    
    # Remove the specific company '^SOX' from the selection
    if '^SOX' in selection:
        selection.remove('^SOX')
    
    # Add the final selection to the list of all selections
    affinity_selections.append(selection)

# %%
#df of return
df=prices[affinity_selections[0]].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(prices[['^SOX']].pct_change().iloc[1:][:split_point])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:len(df.columns)])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AF1, min_cost = optimizer.find_best_k(k_values)

# %%
#df of return
df=prices[affinity_selections[1]].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(prices[['^SOX']].pct_change().iloc[1:][:split_point])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:len(df.columns)])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AF2, min_cost = optimizer.find_best_k(k_values)

# %%
#df of return
df=prices[affinity_selections[2]].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(prices[['^SOX']].pct_change().iloc[1:][:split_point])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:len(df.columns)])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AF3, min_cost = optimizer.find_best_k(k_values)

# %%
#df of return
df=prices[affinity_selections[3]].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(prices[['^SOX']].pct_change().iloc[1:][:split_point])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:len(df.columns)])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AF4, min_cost = optimizer.find_best_k(k_values)

# %%
#df of return
df=prices[affinity_selections[4]].pct_change().iloc[1:]

#Split data into train and test
split_point = int(len(df) * 0.7)
train_data = df[:split_point]
test_data = df[split_point:]

#Optimization 
R_i = np.array(prices[['^SOX']].pct_change().iloc[1:][:split_point])  # Returns for asset/portfolio i (n, 1)
R_x = np.array(train_data.iloc[:,:len(df.columns)])  # Explanatory variables/factors (n, k)
optimizer = GradientDescentOptimizer(R_i, R_x)
k_values = np.linspace(0.01, 1, 100)  # k values to test
best_k, best_W_AF5, min_cost = optimizer.find_best_k(k_values)

# %% [markdown]
# #### Evolution of returns

# %% [markdown]
# #### Evolution of cumulative return Train Period

# %%
# Calcul du Benchmark
Index = prices[:split_point]['^SOX'] / prices[:split_point]['^SOX'].iloc[0]

# Calcul des rendements quotidiens des actifs dans le portefeuille
daily_returns_full = prices.pct_change().iloc[1:][:split_point].drop(columns=['^SOX'])
daily_returns_AE = prices[Autoencoder_stocks].pct_change().iloc[1:][:split_point].drop(columns=['^SOX'])
daily_returns_AF1 = prices[affinity_selections[0]].pct_change().iloc[1:][:split_point]
daily_returns_AF2 = prices[affinity_selections[1]].pct_change().iloc[1:][:split_point]
daily_returns_AF3 = prices[affinity_selections[2]].pct_change().iloc[1:][:split_point]
daily_returns_AF4 = prices[affinity_selections[3]].pct_change().iloc[1:][:split_point]
daily_returns_AF5 = prices[affinity_selections[4]].pct_change().iloc[1:][:split_point]

# Poids des actifs dans le portefeuille
weights_full = [item[0] for item in best_W_full.tolist()]
weights_AE = [item[0] for item in best_W_AE.tolist()]
weights_AF1 = [item[0] for item in best_W_AF1.tolist()]
weights_AF2 = [item[0] for item in best_W_AF2.tolist()]
weights_AF3 = [item[0] for item in best_W_AF3.tolist()]
weights_AF4 = [item[0] for item in best_W_AF4.tolist()]
weights_AF5 = [item[0] for item in best_W_AF5.tolist()]

# Calcul des rendements pondérés du portefeuille
Tracking_portfolio_full = (daily_returns_full * weights_full).sum(axis=1)
Tracking_portfolio_AE = (daily_returns_AE * weights_AE).sum(axis=1)
Tracking_portfolio_AF1 = (daily_returns_AF1 * weights_AF1).sum(axis=1)
Tracking_portfolio_AF2 = (daily_returns_AF2 * weights_AF2).sum(axis=1)
Tracking_portfolio_AF3 = (daily_returns_AF3 * weights_AF3).sum(axis=1)
Tracking_portfolio_AF4 = (daily_returns_AF4 * weights_AF4).sum(axis=1)
Tracking_portfolio_AF5 = (daily_returns_AF5 * weights_AF5).sum(axis=1)


# Calcul des rendements cumulés du portefeuille
cumulative_return_full = (1 + Tracking_portfolio_full).cumprod()
cumulative_return_AE = (1 + Tracking_portfolio_AE).cumprod()
cumulative_return_AF1 = (1 + Tracking_portfolio_AF1).cumprod()
cumulative_return_AF2 = (1 + Tracking_portfolio_AF2).cumprod()
cumulative_return_AF3 = (1 + Tracking_portfolio_AF3).cumprod()
cumulative_return_AF4 = (1 + Tracking_portfolio_AF4).cumprod()
cumulative_return_AF5 = (1 + Tracking_portfolio_AF5).cumprod()


# Création du DataFrame
results_df = pd.DataFrame({
    'SOX': Index,
    'Tracking Portfolio Full': cumulative_return_full,
    'Tracking Portfolio AE': cumulative_return_AE,
    'Tracking Portfolio AF1': cumulative_return_AF1,
    'Tracking Portfolio AF2': cumulative_return_AF2,
    'Tracking Portfolio AF3': cumulative_return_AF3,
    'Tracking Portfolio AF4': cumulative_return_AF4,
    'Tracking Portfolio AF5': cumulative_return_AF5
})

results_df=results_df.dropna()

# %%
plt.figure(figsize=(20, 10))
plt.plot(results_df['SOX'], label='SOX')
plt.plot(results_df['Tracking Portfolio Full'], label='Tracking Portfolio Full')
plt.plot(results_df['Tracking Portfolio AE'], label='Tracking Portfolio AE')
plt.plot(results_df['Tracking Portfolio AF1'], label='Tracking Portfolio AF1')
plt.plot(results_df['Tracking Portfolio AF2'], label='Tracking Portfolio AF2')
plt.plot(results_df['Tracking Portfolio AF3'], label='Tracking Portfolio AF3')
plt.plot(results_df['Tracking Portfolio AF4'], label='Tracking Portfolio AF4')
plt.plot(results_df['Tracking Portfolio AF5'], label='Tracking Portfolio AF5')


plt.title('Evolution of Tracking Portfolio vs SOX Benchmark')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Evolution of cumulative return Test Period

# %%
# Calcul du Benchmark
Index = prices[split_point:]['^SOX'] / prices[split_point:]['^SOX'].iloc[0]

# Calcul des rendements quotidiens des actifs dans le portefeuille
daily_returns_full = prices.pct_change().iloc[1:][split_point:].drop(columns=['^SOX'])
daily_returns_AE = prices[Autoencoder_stocks].pct_change().iloc[1:][split_point:].drop(columns=['^SOX'])
daily_returns_AF1 = prices[affinity_selections[0]].pct_change().iloc[1:][split_point:]
daily_returns_AF2 = prices[affinity_selections[1]].pct_change().iloc[1:][split_point:]
daily_returns_AF3 = prices[affinity_selections[2]].pct_change().iloc[1:][split_point:]
daily_returns_AF4 = prices[affinity_selections[3]].pct_change().iloc[1:][split_point:]
daily_returns_AF5 = prices[affinity_selections[4]].pct_change().iloc[1:][split_point:]

# Poids des actifs dans le portefeuille
weights_full =[item[0] for item in best_W_full.tolist()]
weights_AE  = [item[0] for item in best_W_AE.tolist()]
weights_AF1 = [item[0] for item in best_W_AF1.tolist()]
weights_AF2 = [item[0] for item in best_W_AF2.tolist()]
weights_AF3 = [item[0] for item in best_W_AF3.tolist()]
weights_AF4 = [item[0] for item in best_W_AF4.tolist()]
weights_AF5 = [item[0] for item in best_W_AF5.tolist()]

# Calcul des rendements pondérés du portefeuille
Tracking_portfolio_full = (daily_returns_full * weights_full).sum(axis=1)
Tracking_portfolio_AE = (daily_returns_AE * weights_AE).sum(axis=1)
Tracking_portfolio_AF1 = (daily_returns_AF1 * weights_AF1).sum(axis=1)
Tracking_portfolio_AF2 = (daily_returns_AF2 * weights_AF2).sum(axis=1)
Tracking_portfolio_AF3 = (daily_returns_AF3 * weights_AF3).sum(axis=1)
Tracking_portfolio_AF4 = (daily_returns_AF4 * weights_AF4).sum(axis=1)
Tracking_portfolio_AF5 = (daily_returns_AF5 * weights_AF5).sum(axis=1)


# Calcul des rendements cumulés du portefeuille
cumulative_return_full = (1 + Tracking_portfolio_full).cumprod()
cumulative_return_AE = (1 + Tracking_portfolio_AE).cumprod()
cumulative_return_AF1 = (1 + Tracking_portfolio_AF1).cumprod()
cumulative_return_AF2 = (1 + Tracking_portfolio_AF2).cumprod()
cumulative_return_AF3 = (1 + Tracking_portfolio_AF3).cumprod()
cumulative_return_AF4 = (1 + Tracking_portfolio_AF4).cumprod()
cumulative_return_AF5 = (1 + Tracking_portfolio_AF5).cumprod()


# Création du DataFrame
results_df = pd.DataFrame({
    'SOX': Index,
    'Tracking Portfolio Full': cumulative_return_full,
    'Tracking Portfolio AE': cumulative_return_AE,
    'Tracking Portfolio AF1': cumulative_return_AF1,
    'Tracking Portfolio AF2': cumulative_return_AF2,
    'Tracking Portfolio AF3': cumulative_return_AF3,
    'Tracking Portfolio AF4': cumulative_return_AF4,
    'Tracking Portfolio AF5': cumulative_return_AF5
})

results_df=results_df.dropna()

# %%
plt.figure(figsize=(20, 10))
plt.plot(results_df['SOX'], label='SOX')
plt.plot(results_df['Tracking Portfolio Full'], label='Tracking Portfolio Full')
plt.plot(results_df['Tracking Portfolio AE'], label='Tracking Portfolio AE')
plt.plot(results_df['Tracking Portfolio AF1'], label='Tracking Portfolio AF1')
plt.plot(results_df['Tracking Portfolio AF2'], label='Tracking Portfolio AF2')
plt.plot(results_df['Tracking Portfolio AF3'], label='Tracking Portfolio AF3')
plt.plot(results_df['Tracking Portfolio AF4'], label='Tracking Portfolio AF4')
plt.plot(results_df['Tracking Portfolio AF5'], label='Tracking Portfolio AF5')


plt.title('Evolution of Tracking Portfolio vs SOX Benchmark')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.legend()
plt.grid(True)
plt.show()
